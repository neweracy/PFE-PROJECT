# %% [markdown]
# ## NAME : KWAKU QUARTEY ANSAH OFEI
#
# ## ID : 10970598
#
# ## DEPARTMENT : MATERIAL ENGINEERING
#
# ---

# %% [markdown]
# #### IMPORTING PACKAGES

# %%
# importing pandas
from pandas import pandas as pd

# %%
# importing matplotlib
from matplotlib import pyplot as plt

# %%
# importing seaborn
import seaborn as sns

# %% [markdown]
# #### GETTING THE REQUIRED DATA FROM 'data.csv' file

# %%
# assigning dataset to the information in ./data.csv file

dataset = pd.read_csv('./data.csv')

# %% [markdown]
# #### CLEANING UP THE DATA ( REMOVING ALL NULL VALUES AND DUPLICATES )
# ---

# %%
# This removes all the spaces between words in the columns and replaces them with underscores '_'
dataset.columns = dataset.columns.str.replace(' ', '_')

# %%
dataset
# Out:
#         ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# ...

# %%
# checking the information about the data
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed_acidity         1600 non-null   float64
#  2   volatile_acidity      1601 non-null   float64
#  3   citric_acid           1600 non-null   float64
#  4   residual_sugar        1601 non-null   float64
#  5   chlorides             1598 non-null   float64
#  6   free_sulfur_dioxide   1600 non-null   float64
#  7   total_sulfur_dioxide  1600 non-null   float64
#  8   density               1600 non-null   float64
#  9   pH                    1600 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1600 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %% [markdown]
# <p>
#   The isnull() method is used to check whether a value in a pandas DataFrame or Series is missing or not. This method returns a boolean mask indicating where the values are null (True) or not null (False).
# </p>

# %%
# checking for null values
dataset.isnull().sum()
# Out:
# ID                      0
# fixed_acidity           1
# volatile_acidity        0
# citric_acid             1
# residual_sugar          0
# chlorides               3
# free_sulfur_dioxide     1
# total_sulfur_dioxide    1
# density                 1
# pH                      1
# sulphates               0
# alcohol                 0
# quality                 1
# dtype: int64

# %%
# this code is to find the mean of each of the columns
dataset_mean_data = dataset.mean()

# %%
# this variable represents the mean of each column of the dataset
dataset_mean_data
# Out:
# ID                      801.000000
# fixed_acidity             8.319875
# volatile_acidity          0.527742
# citric_acid               0.271175
# residual_sugar            2.538445
# chlorides                 0.087487
# free_sulfur_dioxide      15.886875
# total_sulfur_dioxide     46.520000
# density                   0.996746
# pH                        3.311106
# sulphates                 0.658220
# alcohol                  10.423204
# quality                   5.636250
# dtype: float64

# %% [markdown]
# #### REPLACING ALL NULL VALUES WITH THE MEAN OF EACH COLUMN AND REMOVING ALL DUPLICATES

# %% [markdown]
# <p>We can fill null values with the mean, median, or mode of the respective column using the fillna() method. This is a common approach and is useful when there are only a few null values in the dataset just like this dataset which we will be using the mean value and the drop_duplicate() method drop all duplicates in the dataset.</p>

# %%
dataset = dataset.fillna(dataset_mean_data).drop_duplicates()

# %% [markdown]
# ### ASSIGNING THE MEAN OF EACH COLUMN TO VARIABLES

# %%
meanFA = dataset.fixed_acidity.mean()
meanVA = dataset.volatile_acidity.mean()
meanCA = dataset.citric_acid.mean()
meanRS = dataset.residual_sugar.mean()
meanC = dataset.chlorides.mean()
meanFSD = dataset.free_sulfur_dioxide.mean()
meanTSD = dataset.total_sulfur_dioxide.mean()
meanD = dataset.density.mean()
meanPH = dataset.pH.mean()
meanS = dataset.sulphates.mean()
meanA = dataset.alcohol.mean()
meanQ = dataset.quality.mean()
indexing = dataset.index

# %% [markdown]
# #### THIS IS THE SUMMARY OF THE STATISTICS OF THE DATASET

# %% [markdown]
# <p>The describe() method gives us the count, mean, standard deviation, minimum, and maximum values of the dataset or individual column.</p>

# %%
dataset.describe()
# Out:
#                 ID  fixed_acidity  volatile_acidity  citric_acid  \
# count  1601.000000    1601.000000       1601.000000  1601.000000
# mean    801.000000       8.319875          0.527742     0.271175
# std     462.313206       1.739495          0.178981     0.194684
# min       1.000000       4.600000          0.120000     0.000000
# 25%     401.000000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1201.000000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual_sugar    chlorides  free_sulfur_dioxide  total_sulfur_dioxide  \
# count     1601.000000  1601.000000          1601.000000           1601.000000
# mean         2.538445     0.087487            15.886875             46.520000
# std          1.409138     0.047032            10.455218             32.967416
# ...

# %% [markdown]
# #### THE MEAN FOR EACH COLUMN

# %%
print(f'The mean value of fixed_acidity  is {meanFA}')
print(f'The mean value of volatile_acidity is {meanVA}')
print(f'The mean value of citric_acid is {meanCA}')
print(f'The mean value of residual_sugar is {meanRS}')
print(f'The mean value of chlorides is {meanC}')
print(f'The mean value of free_sulfur_dioxide is {meanFSD}')
print(f'The mean value of total_sulfur_dioxide is {meanTSD}')
print(f'The mean value of density is {meanD}')
print(f'The mean value of pH is {meanPH}')
print(f'The mean value of sulphate is {meanS}')
print(f'The mean value of alcohol is {meanA}')
print(f'The mean value of quality is {meanQ}')
# Out:
# The mean value of fixed_acidity  is 8.319875
# The mean value of volatile_acidity is 0.5277420362273579
# The mean value of citric_acid is 0.27117500000000005
# The mean value of residual_sugar is 2.5384447220487196
# The mean value of chlorides is 0.0874874843554443
# The mean value of free_sulfur_dioxide is 15.886875
# The mean value of total_sulfur_dioxide is 46.52
# The mean value of density is 0.9967456437500001
# The mean value of pH is 3.3111062500000004
# The mean value of sulphate is 0.6582198625858838
# The mean value of alcohol is 10.42320424734541
# The mean value of quality is 5.6362499999999995

# %% [markdown]
# ## GRAPHING THE DATA
# ---

# %% [markdown]
# We can see some hidden inferences visually through the graphs. The Bar graphs, Pie charts, and histograms show the distributions , outliner and relationships among variables in the dataset

# %%
# data for pie chart
# total columns excluding ID is 12
colors = ['red', 'orange', 'yellow', 'green', 'blue', 'purple',
          'pink', 'brown', 'gray', 'black', 'violet', 'beige']
explode = (0.5, 0.5, 1, 1, 1, 0, 0, 0.5, 0, 0.5, 0, 0.5)
mean_values = [meanFA, meanVA, meanCA, meanRS, meanC,
              meanFSD, meanTSD, meanD, meanPH, meanS, meanA, meanQ]
mean_topics = ['FA',
              'VA',
              'CA',
              'RS',
              'C',
              'FSD',
              'TSD',
              'density',
              'pH',
              'sulphates',
              'alcohol',
              'quality']

# %%
x_title = 'Column names'
y_title = 'Mean Values'
legendLabels = ['fixed_acidity (FA)',
                'volatile_acidity (VA)',
                'citric_acid (CA)',
                'residual_sugar (RS)',
                'chlorides (C)',
                'free_sulfur_dioxide (FSD)',
                'total_sulfur_dioxide (TSD)',
                'density',
                'pH',
                'sulphates',
                'alcohol',
                'quality']

# %%
labels = mean_topics
sizes = mean_values

# %% [markdown]
# #### COMPARING THE MEAN VALUES OF THE DATA USING A PIE CHART

# %%
# plotting the pie chart
plt.pie(sizes, labels=labels, explode=explode,
        autopct='%1.1f%%', pctdistance=1.01, shadow=True, colors=colors, labeldistance=1.2)
plt.axis('equal')
plt.legend(title='index', labels=legendLabels, loc='upper left',)
plt.title('Mean Values for each of the columns in a pie chart')
plt.figure(figsize=(15, 18))
plt.show()

# %% [markdown]
# #### COMPARING THE MEAN VALUES OF THE DATA USING A BAR GRAPH

# %%
# plotting a bar graph

fig = plt.figure(figsize=(10, 5))

plt.bar(labels, sizes, width=0.5, color=colors)
plt.xlabel(x_title)
plt.ylabel(y_title)
plt.title('Comparing mean of columns in a bar chart')
plt.legend(loc='upper right', )
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
dataset
# Out:
#         ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density        pH  \
# ...

# %% [markdown]
# ### HISTOGRAM OF EACH COLUMN IN THE DATASET
# ---

# %%
# histogram of columns
sns.histplot(data=dataset, x=dataset['fixed_acidity'],kde=True)
# Out:
# <AxesSubplot: xlabel='fixed_acidity', ylabel='Count'>

# %%
sns.histplot(data=dataset, x=dataset['volatile_acidity'],kde=True)
# Out:
# <AxesSubplot: xlabel='volatile_acidity', ylabel='Count'>

# %%
sns.histplot(data=dataset, x=dataset['citric_acid'],kde=True)
# Out:
# <AxesSubplot: xlabel='citric_acid', ylabel='Count'>

# %%
sns.histplot(data=dataset, x=dataset['residual_sugar'],kde=True)
# Out:
# <AxesSubplot: xlabel='residual_sugar', ylabel='Count'>

# %%
plt.figure(figsize=(8,6))
sns.histplot(data=dataset, x=dataset['chlorides'],kde=True)
# Out:
# <AxesSubplot: xlabel='chlorides', ylabel='Count'>

# %%
sns.histplot(data=dataset, x=dataset['free_sulfur_dioxide'],kde=True)
# Out:
# <AxesSubplot: xlabel='free_sulfur_dioxide', ylabel='Count'>

# %%
sns.histplot(data=dataset, x=dataset['total_sulfur_dioxide'],kde=True)
# Out:
# <AxesSubplot: xlabel='total_sulfur_dioxide', ylabel='Count'>

# %%
sns.histplot(data=dataset, x=dataset['density'],kde=True)
# Out:
# <AxesSubplot: xlabel='density', ylabel='Count'>

# %%
sns.histplot(data=dataset, x=dataset['pH'],kde=True)
# Out:
# <AxesSubplot: xlabel='pH', ylabel='Count'>

# %%
sns.histplot(data=dataset, x=dataset['sulphates'],kde=True)
# Out:
# <AxesSubplot: xlabel='sulphates', ylabel='Count'>

# %%
sns.histplot(data=dataset, x=dataset['alcohol'],kde=True)
# Out:
# <AxesSubplot: xlabel='alcohol', ylabel='Count'>

# %% [markdown]
# #### DATA CORRELATION

# %%
dataset_corr = dataset.corr()

# %%
dataset_corr
# Out:
#                             ID  fixed_acidity  volatile_acidity  citric_acid  \
# ID                    1.000000      -0.267899         -0.009544    -0.153294
# fixed_acidity        -0.267899       1.000000         -0.255557     0.670856
# volatile_acidity     -0.009544      -0.255557          1.000000    -0.552909
# citric_acid          -0.153294       0.670856         -0.552909     1.000000
# residual_sugar       -0.031589       0.114595          0.001877     0.143517
# chlorides            -0.119131       0.093472          0.060748     0.203981
# free_sulfur_dioxide   0.091145      -0.152932         -0.010591    -0.061252
# total_sulfur_dioxide -0.113809      -0.113325          0.076247     0.036014
# density              -0.368725       0.667693          0.022753     0.364104
# pH                    0.135082      -0.682452          0.235182    -0.542637
# sulphates            -0.124243       0.182291         -0.261364     0.312839
# ...

# %% [markdown]
# #### HEATMAP OF THE DATA CORRELATION

# %% [markdown]
# <p>
#    The correlation matrix provides us with the correlation value between each set of dataset's column pairs. If the correlation coefficient is positive, there is a positive correlation between the variables; if the correlation coefficient is negative, there is a negative connection between the variables. No association is seen when the coefficient is 0.
# </p>

# %%
plt.figure(figsize=(9,6))
sns.heatmap(dataset_corr, annot=True, fmt='0.1g',cmap='magma')
# Out:
# <AxesSubplot: >

# %%
plt.rcParams
# Out:
# RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': ['-layers', 'OptimizePlus'],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
#           'axes.axisbelow': 'line',
#           'axes.edgecolor': 'black',
#           'axes.facecolor': 'white',
#           'axes.formatter.limits': [-5, 6],
#           'axes.formatter.min_exponent': 0,
#           'axes.formatter.offset_threshold': 4,
#           'axes.formatter.use_locale': False,
#           'axes.formatter.use_mathtext': False,
#           'axes.formatter.useoffset': True,
# ...

# %% [markdown]
# # INFERENCES MADE

# %% [markdown]
# ### The firm's focus would be on **quality** because it is a wine company.
#
#
# ---
#
# | Parameter            | Correlation with wine quality | Inference                                                                    |
# | -------------------- | ----------------------------- | ---------------------------------------------------------------------------- |
# | fixed_acidity        | 0.1                           | Quality slightly increases with an increase in the fixed acidity             |
# | volatile acidity     | -0.4                          | Quality decreases with an increase in volatile acidity                       |
# | citric_acid          | 0.2                           | Quality slightly increases with an increase in citric acid concentration     |
# | residual_sugar       | 0.01                          | There is a negligible increase in Quality with an increase in residual sugar |
# | chlorides            | -0.1                          | Quality slightly decreases with increasing concentration of chlorides        |
# | free_sulfur_dioxide  | -0.05                         | Quality barely decreases with increasing free sulphur dioxide                |
# | total_sulfur_dioxide | -0.2                          | Quality decreases with increasing total sulphur dioxide concentration        |
# | density              | -0.2                          | Quality decreases with increasing density                                    |
# | pH                   | -0.06                         | Quality barely decreases with increasing pH                                  |
# | sulphates            | 0.3                           | Quality slightly increases with increasing sulphates                         |
# | alcohol              | 0.5                           | Quality increases with increasing alcohol                                    |
